# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-qFOf5Qjw5fH6bPBx6d374d643f7140A4Bc67C51989222a71"
os.environ["OPENAI_API_BASE"] = "https://chatapi.onechat.fun/v1"

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

import os
os.environ["OPENAI_API_KEY"] = "sk-qFOf5Qjw5fH6bPBx6d374d643f7140A4Bc67C51989222a71"
os.environ["OPENAI_API_BASE"] = "https://chatapi.onechat.fun/v1"

chat = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0, verbose=True)
response = chat([
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="What is the weather like in HuiZhou?")
])
print(response)
# Out:
# content="I don't have access to real-time data, including current weather conditions. You can check the weather in Huizhou by using a weather website or app like Weather.com, AccuWeather, or your preferred local weather service. They can provide you with up-to-date information on the current weather, forecasts, and any weather advisories for Huizhou." response_metadata={'token_usage': {'completion_tokens': 72, 'prompt_tokens': 17, 'total_tokens': 89}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-eb9727e9-e962-482e-9e20-244436c3790b-0'

# %%
from langchain_openai.llms import OpenAI

llm = OpenAI(model="text-davinci-002")
response = llm.invoke("What is AI?")

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

chat = ChatOpenAI(temperature=0)
response = chat.invoke([
    SystemMessage(content="You are a chatbot that knows nothing about AI. When you are asked about AI, you must say 'I do not know!'"),
    HumanMessage(content="What is AI?"),
])
print(response)
# Out:
# content='I do not know!' response_metadata={'token_usage': {'completion_tokens': 5, 'prompt_tokens': 31, 'total_tokens': 36}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-02747992-d2df-4b65-ab7f-20811283949e-0'

# %%
response.__class__
# Out:
# langchain_core.messages.ai.AIMessage

# %%
from langchain_community.document_loaders.text import TextLoader

loader = TextLoader("./huggingface_demo.py")
docs = loader.load()

# %%
docs[0].page_content
# Out:
# 'import gradio as gr\nfrom huggingface_hub import InferenceClient\n\n\n\nif gr.NO_RELOAD:\n    client = InferenceClient(token="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")\n\nsystem_message = {\n    "role": "system",\n    "content": """\nYou are a helpful assistant.\nYou will be given a question and a set of answers along with a confidence score between 0 and 1 for each answer.\nYou job is to turn this information into a short, coherent response.\nFor example:\nQuestion: "Who is being invoiced?", answer: {"answer": "John Doe", "confidence": 0.98}\nYou should respond with something like:\nWith a high degree of confidence, I can say John Doe is being invoiced.\nQuestion: "What is the invoice total?", answer: [{"answer": "154.08", "confidence": 0.75}, {"answer": "155", "confidence": 0.25}\nYou should respond with something like:\nI belive the invoice total is $154.08 thought it can also be $155.\n"""}\n\ndef chat_fn(multimodal_message):\n    question = multimodal_message["text"]\n    image =
# ...

# %%
from langchain_text_splitters.character import CharacterTextSplitter

text_splitter = CharacterTextSplitter(
    separator= "\n\n",
    chunk_size = 1000,
    chunk_overlap = 200,
    length_function = len
)

split_docs = text_splitter.split_documents(docs)

# %%
split_docs
# Out:
# [Document(page_content='import gradio as gr\nfrom huggingface_hub import InferenceClient\n\nif gr.NO_RELOAD:\n    client = InferenceClient(token="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")\n\nsystem_message = {\n    "role": "system",\n    "content": """\nYou are a helpful assistant.\nYou will be given a question and a set of answers along with a confidence score between 0 and 1 for each answer.\nYou job is to turn this information into a short, coherent response.\nFor example:\nQuestion: "Who is being invoiced?", answer: {"answer": "John Doe", "confidence": 0.98}\nYou should respond with something like:\nWith a high degree of confidence, I can say John Doe is being invoiced.\nQuestion: "What is the invoice total?", answer: [{"answer": "154.08", "confidence": 0.75}, {"answer": "155", "confidence": 0.25}\nYou should respond with something like:\nI belive the invoice total is $154.08 thought it can also be $155.\n"""}', metadata={'source': './huggingface_demo.py'}),
# ...

# %%
from langchain_text_splitters.python import PythonCodeTextSplitter

python_splitter = PythonCodeTextSplitter(
    chunk_size=50,
    chunk_overlap=0
)


python_docs = python_splitter.split_text(docs[0].page_content)

# %%
python_docs
# Out:
# ['import gradio as gr',
#  'from huggingface_hub import InferenceClient',
#  'if gr.NO_RELOAD:',
#  'client =',
#  'InferenceClient(token="hf_bGBanGbfOgWinwEmjcubyYo',
#  'CtdYbAQxgAO")',
#  'system_message = {\n    "role": "system",',
#  '"content": """\nYou are a helpful assistant.',
#  'You will be given a question and a set of answers',
#  'along with a confidence score between 0 and 1 for',
#  'each answer.',
#  'You job is to turn this information into a short,',
#  'coherent response.',
#  'For example:',
#  'Question: "Who is being invoiced?", answer:',
#  '{"answer": "John Doe", "confidence": 0.98}',
#  'You should respond with something like:',
#  'With a high degree of confidence, I can say John',
#  'Doe is being invoiced.',
#  'Question: "What is the invoice total?", answer:',
#  '[{"answer": "154.08", "confidence": 0.75},',
#  '{"answer": "155", "confidence": 0.25}',
#  'You should respond with something like:',
#  'I belive the invoice total is $154.08 thought it',
# ...

# %%
from langchain_text_splitters.character import RecursiveCharacterTextSplitter
from langchain_text_splitters.base import Language

python_splitter_character = RecursiveCharacterTextSplitter.from_language(
    chunk_size=50, chunk_overlap=0, language=Language.PYTHON
)

splitted_code = python_splitter.split_text(docs[0].page_content)

# %%
splitted_code
# Out:
# ['import gradio as gr\nfrom huggingface_hub import InferenceClient\n\n\n\nif gr.NO_RELOAD:\n    client = InferenceClient(token="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")\n\nsystem_message = {\n    "role": "system",\n    "content": """\nYou are a helpful assistant.\nYou will be given a question and a set of answers along with a confidence score between 0 and 1 for each answer.\nYou job is to turn this information into a short, coherent response.\nFor example:\nQuestion: "Who is being invoiced?", answer: {"answer": "John Doe", "confidence": 0.98}\nYou should respond with something like:\nWith a high degree of confidence, I can say John Doe is being invoiced.\nQuestion: "What is the invoice total?", answer: [{"answer": "154.08", "confidence": 0.75}, {"answer": "155", "confidence": 0.25}\nYou should respond with something like:\nI belive the invoice total is $154.08 thought it can also be $155.\n"""}\n\ndef chat_fn(multimodal_message):\n    question = multimodal_message["text"]\n    image 
# ...

# %%
from langchain_text_splitters.markdown import MarkdownTextSplitter

markdown_document = "# Chapter 1\n\n    ## Section 1\n\nHi this is the 1st section\n\nWelcome\n\n ### Module 1 \n\n Hi this is the first module \n\n ## Section 2\n\n Hi this is the 2nd section"

headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
    ("####", "Header 4"),
    ("#####", "Header 5"),
    ("######", "Header 6")
]
splitter = MarkdownTextSplitter(chunk_size=50, chunk_overlap=0)
splits = splitter.split_text(markdown_document)
splits
# Out:
# ['# Chapter 1\n\n    ## Section 1',
#  'Hi this is the 1st section\n\nWelcome',
#  '### Module 1 \n\n Hi this is the first module',
#  '## Section 2\n\n Hi this is the 2nd section']

# %%
from langchain_text_splitters.character import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 50,
    chunk_overlap  = 20,
    length_function = len,
    separators = ["\n\n", "\n", " ", ""]
)

texts = text_splitter.split_documents(docs)
texts
# Out:
# [Document(page_content='import gradio as gr', metadata={'source': './huggingface_demo.py'}),
#  Document(page_content='from huggingface_hub import InferenceClient', metadata={'source': './huggingface_demo.py'}),
#  Document(page_content='if gr.NO_RELOAD:', metadata={'source': './huggingface_demo.py'}),
#  Document(page_content='client =', metadata={'source': './huggingface_demo.py'}),
#  Document(page_content='InferenceClient(token="hf_bGBanGbfOgWinwEmjcubyYo', metadata={'source': './huggingface_demo.py'}),
#  Document(page_content='anGbfOgWinwEmjcubyYoCtdYbAQxgAO")', metadata={'source': './huggingface_demo.py'}),
#  Document(page_content='system_message = {\n    "role": "system",', metadata={'source': './huggingface_demo.py'}),
#  Document(page_content='"content": """\nYou are a helpful assistant.', metadata={'source': './huggingface_demo.py'}),
#  Document(page_content='You will be given a question and a set of answers', metadata={'source': './huggingface_demo.py'}),
# ...

# %%
from langchain_text_splitters.character import CharacterTextSplitter
token_spliter = CharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=100, chunk_overlap=0
)
split_docs = token_spliter.split_documents(docs)
split_docs
# Out:
# Created a chunk of size 200, which is longer than the specified 100
# Created a chunk of size 251, which is longer than the specified 100
# Created a chunk of size 114, which is longer than the specified 100
# [Document(page_content='import gradio as gr\nfrom huggingface_hub import InferenceClient\n\nif gr.NO_RELOAD:\n    client = InferenceClient(token="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")', metadata={'source': './huggingface_demo.py'}),
# ...

# %%
## 向量化文本分块

# %%
from langchain_openai.embeddings import OpenAIEmbeddings
embedding_model = OpenAIEmbeddings()
embeddings = embedding_model.embed_documents([t.page_content for t in split_docs])
embeddings
# Out:
# [[-0.010702125929821582,
#   0.005750184899587284,
#   -0.003238894081401437,
#   -0.026320872286808742,
#   -0.00038057889306543683,
#   0.013845654202937452,
#   -0.011507434999788407,
#   -0.0005439364472582599,
#   -0.018691634623965687,
#   -0.04433435385185517,
#   0.01864924862028311,
#   -0.0079329951892341,
#   0.007297225033997149,
#   -0.009176278797253006,
#   0.0008847796768713847,
#   0.0035020323042633996,
#   0.005827890506338499,
#   0.01675606845579992,
#   0.031562442742206605,
#   -0.037383269247931374,
#   0.007763456274504229,
#   0.014163539230555924,
#   -0.004955472830541149,
#   -0.03481193302452867,
#   -0.014481424258174396,
#   -0.01140147299058222,
#   0.0234810990400837,
#   -0.03452936899997895,
#   0.010292406894224395,
#   -0.015032425306046442,
#   0.00024967212169200114,
#   -0.021008661825273528,
#   -0.020952148820363576,
#   -0.01675606845579992,
#   -0.010172317883790825,
#   -0.013513641674091555,
#   0.01164871651206322,
# ...

# %%
# %pip install -q chromadb
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders.text import TextLoader
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_text_splitters.markdown import MarkdownTextSplitter
# from langchain.vectorstores.chroma import Chroma
from langchain_chroma.vectorstores import Chroma

docs = TextLoader("written_docs.md").load()

split_docs = MarkdownTextSplitter(chunk_size=1000, chunk_overlap=0).split_documents(docs)

db = Chroma.from_documents(split_docs, OpenAIEmbeddings())

docs
split_docs
db

# %%
query = "为什么我要自建图床？"

docs = db.similarity_search(query)
print(docs[0].page_content)
# Out:
# ---
# 类型:
#   - 效率工具
#   - 数据备份
# ---
# # 为什么要做这件事情？
#
# 1. 为什么需要图床？
#    A：文章发布到公众号B站等平台，比较方便
# 2. Obsidian如何快速上传和使用图床上的图片？
#    A：Image-Auto-Upload-plugin + PicList + WebDav服务器
#    功能：
#    - WebDav服务器：用来存放照片，并且通过连接可以直接访问
#    - PicList：基于PicGo的改进版图片上传工具，直接支持WebDav服务器
#    - Image-Auto-Upload-plugin：Obsidian内的图片自动上传工具，用来自动触发PicGo的上传操作
# -
# 3. 选择什么平台？
#    A：商用平台：
#    - OSS：数据迁移困难（感觉上），收费
#    - Github：访问慢，不一定总能访问到
# 4. 自建图床的优缺点？适合什么情况？
#    A：优点：
#    - 国内可以访问到
#    - 如果已经租过服务器，可以直接用它。没租过的话，一年100元以内
#    - 使用免费的坚果云也可以
#    - 数据完全由自己控制，想怎么来就怎么来
#     缺点：
#    - Image-Auto-Upload-plugin不支持手机版Obsidian
#    - 需要自己配置
#
# # 配置过程
# ## 第一部分：技术选择和服务器准备
#
# 我对图床的要求：
# - 无需密码可以直接查看图片
# - 增删图片需要密码
# - 配置足够简单，并且尽可能支持多平台
#
# ...

# %% [markdown]
# ## Prompt 提示词学习
#
# 提示词（Prompt）是指向模型提供的输入。这个输入通常由多个元素构成。LangChain 提供了一系列的类和函数，简化构建和处理提示词的过程。
#
# - 提示词模板（Prompt Template）：对提示词参数化，提高代码的重用性。
# - 示例选择器（Example Selector）：动态选择要包含在提示词中的示例

# %%
from langchain_core.prompts import PromptTemplate

template = """
你精通多种语言，是专业的翻译官。你负责{src_lang}到{dst_lang}的翻译。
"""

prompt = PromptTemplate.from_template(template)
prompt.format(src_lang="English", dst_lang="Chinese")
# Out:
# '\n你精通多种语言，是专业的翻译官。你负责English到Chinese的翻译。\n'

# %%
prompt = PromptTemplate(
    input_variables=["animal1", "animal2"],
    template="{animal1} {animal1}, what do you see? I see a {animal2} looking at me."
)

prompt.format(animal1="Brown Bear", animal2="Yellow Duck")
# Out:
# 'Brown Bear Brown Bear, what do you see? I see a Yellow Duck looking at me.'

# %% [markdown]
# ### 聊天提示词模板
#
# 聊天模型，比如 OpenAI 的GPT模型，接受一系列聊天消息作为输入，每条消息都与一个角色相关联。这个消息列表通常以一定格式串联，构成模型的输入，也就是提示词。
#
# LangChain提供了一系列模板，以便更轻松地构建和处理提示词。建议在与聊天模型交互时优先选择使用这些与聊天相关的模板，而不是基础的PromptTemplate，以充分利用框架的优势，提高开发效率。SystemMessagePromptTemplate, AIMessagePromptTemplate, HumanMessagePromptTemplate 是分别用于创建不同角色提示词的模板。

# %%
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate, HumanMessagePromptTemplate, SystemMessagePromptTemplate, AIMessagePromptTemplate

from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

system_template = "You are a professional translator that translates {src_lang} to {tgt_lang}"
system_message_prompt = SystemMessagePromptTemplate.from_template(system_template)
system_message_prompt

user_template = "Sentence to be translated: {user_input}"
user_message_prompt = HumanMessagePromptTemplate.from_template(user_template)

chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, user_message_prompt])
chat_prompt.format_prompt(src_lang="English", tgt_lang="French", user_input="I love programming").to_messages()
# Out:
# [SystemMessage(content='You are a professional translator that translates English to French'),
#  HumanMessage(content='Sentence to be translated: I love programming')]

# %% [markdown]
# 样本选择器
# 在LLM应用开发中，可能需要从大量样本数据中，选择部分数据包含在提示词中。样本选择器（Example Selector）正是满足该需求的组件，它也通常与少样本提示词配合使用。LangChain 提供了样本选择器的基础接口类 BaseExampleSelector，每个选择器类必须实现的函数为 select_examples。LangChain 实现了若干基于不用应用场景或算法的选择器：
#
# LengthBasedExampleSelector
# MaxMarginalRelevanceExampleSelector
# NGramOverlapExampleSelector
# SemanticSimilarityExampleSelector

# %%
from langchain_core.prompts import PromptTemplate, FewShotPromptTemplate
from langchain_core.example_selectors import LengthBasedExampleSelector

examples = [
    {"input": "happy", "output": "good"},
    {"input": "sad", "output": "bad"},
    {"input": "angry", "output": "bad"},
    {"input": "tired", "output": "bad"},
    {"input": "excited", "output": "good"},
    {"input": "bored", "output": "bad"},
    {"input": "hungry", "output": "bad"},
    {"input": "sleepy", "output": "bad"},
    {"input": "happy", "output": "good"},
    {"input": "sad", "output": "bad"},
    {"input": "angry", "output": "bad"},
    {"input": "tired","output": "bad"},
]

prompt_template = PromptTemplate(
    input_variables=["input", "output"],
    template="Input: {input} \nOutput: {output}",
)

example_selector = LengthBasedExampleSelector(
    examples=examples,
    example_prompt=prompt_template,
    max_length=25
)

few_shot_prompt = FewShotPromptTemplate(
    example_selector=example_selector,
    example_prompt=prompt_template,
    prefix="Given the input, classify it as either good or bad",
    suffix="Input: {input} \nOutput:",
    input_variables=["input"],
)

print(few_shot_prompt.format(input="happy"))
# Out:
# Given the input, classify it as either good or bad
#
# Input: happy
# Output: good
#
# Input: sad
# Output: bad
#
# Input: angry
# Output: bad
#
# Input: tired
# Output: bad
#
# Input: happy
# Output:

# %% [markdown]
# ## LangChain支持的输出解析器
# LangChain框架提供了一系列解析器实现来满足应用在不同功能场景中的需求。它们包括且不局限于如下解析器：
#
# - List parser
# - Datetime parser
# - Enum parser
# - Auto-fixing parser
# - Pydantic parser
# - Retry parser
# - Structured output parser

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser

output_parser = CommaSeparatedListOutputParser()
output_parser.parse("Black, yellow, red, green, white, blue")
# Out:
# ['Black', 'yellow', 'red', 'green', 'white', 'blue']

# %%
from langchain.output_parsers import StructuredOutputParser, ResponseSchema
from langchain.prompts import PromptTemplate, ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_openai.llms import OpenAI

output_parser = StructuredOutputParser.from_response_schemas([
    ResponseSchema(name="answer", description="The answer to the users question"),
    ResponseSchema(name="source", description="The sources used to answer the users question, should be a website.")
])

format_instructions = output_parser.get_format_instructions()

prompt = PromptTemplate(
    template="Answer the users question as best as possible.\n{format_instructions}\n{question}",
    input_variables=["question"],
    partial_variables={"format_instructions": format_instructions}
)

model = OpenAI(temperature=0)
response = prompt.format_prompt(question="What is the capital of France?")
print(response)
output = model(response.to_string())
print(output)
output_parser.parse(output)
# Out:
# text='Answer the users question as best as possible.\nThe output should be a markdown code snippet formatted in the following schema, including the leading and trailing "```json" and "```":\n\n```json\n{\n\t"answer": string  // The answer to the users question\n\t"source": string  // The sources used to answer the users question, should be a website.\n}\n```\nWhat is the capital of France?'
#
#
# ```json
# {
# 	"answer": "Paris",
# 	"source": "https://en.wikipedia.org/wiki/Paris"
# }
# ```
# {'answer': 'Paris', 'source': 'https://en.wikipedia.org/wiki/Paris'}
